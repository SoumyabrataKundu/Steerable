# %%
import Steerable.nn.utils as u
import Steerable.nn.utils1 as u1

# %%
kernel_size = [3,3]
freq_cutoff = 8
F = u.get_CFint_matrix(kernel_size, 4, 1000, freq_cutoff, freq_cutoff, 1)
F1 = u1.get_CFint_matrix(kernel_size, 4, 1000, freq_cutoff, 1)

# %%
import torch
torch.round(F.abs(), decimals=4)
# Out:
# tensor([[[[[1.2000e-03, 1.7400e-02, 1.2000e-03],
#            [1.7400e-02, 1.7540e-01, 1.7400e-02],
#            [1.2000e-03, 1.7400e-02, 1.2000e-03]],
#
#           [[9.9000e-03, 5.9700e-02, 9.9000e-03],
#            [5.9700e-02, 2.2150e-01, 5.9700e-02],
#            [9.9000e-03, 5.9700e-02, 9.9000e-03]],
#
#           [[3.3600e-02, 1.1190e-01, 3.3600e-02],
#            [1.1190e-01, 1.6810e-01, 1.1190e-01],
#            [3.3600e-02, 1.1190e-01, 3.3600e-02]],
#
#           [[7.9600e-02, 1.5920e-01, 7.9600e-02],
#            [1.5920e-01, 4.5100e-02, 1.5920e-01],
#            [7.9600e-02, 1.5920e-01, 7.9600e-02]]],
#
#
#          [[[0.0000e+00, 0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00, 0.0000e+00],
# ...
